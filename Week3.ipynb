# %% [markdown]
# <a href="https://colab.research.google.com/github/sitiaisyah14/PCVK_Genap_2023/blob/main/Week3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
from google.colab.patches import cv2_imshow

# %% [markdown]
# # **Transformasi Linier Brightness**
#
# 𝑔(𝑥, 𝑦) = 𝑓(𝑥, 𝑦) + 𝑏
#
# g(x,y) adalah nilai pixel setelah transformasi, f(x,y) adalah nilai pixel asli, dan b adalah
# nilai brightness

# %%
print('Mengubah tingkat kecerahan citra')
print('--------------------------------')
try:
  brightness = int(input('masukkan nilai kecerahan: '))
except ValueError:
  print('Error, not a number')


original = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/female.tiff')
brightness_image = np.zeros(original.shape, original.dtype)

#Akses per piksel
for y in range(original.shape[0]):
  for x in range(original.shape[1]):
    for c in range(original.shape[2]):
      brightness_image[y,x,c] = np.clip(original[y,x,c] + brightness, 0, 255)


#Cara sederhana tanpa loop
#brightness_image = cv.convertScaleAbs(original, beta=brightness)

final_frame = cv.hconcat((original, brightness_image))
cv2_imshow(final_frame)
# Out:
# Mengubah tingkat kecerahan citra
# --------------------------------
# masukkan nilai kecerahan: 60
# <PIL.Image.Image image mode=RGB size=512x256 at 0x7F807AFC35B0>

# %% [markdown]
# # **TugasPraktikum**
#
# **Implementasikan transformasi contrast**

# %%
print('Mengubah Kontras dan Tingkat Kecerahan Citra')
print('--------------------------------------------')
try:
  brightness_level = int(input('masukkan nilai kecerahan [-255 - 255]: '))
  contrast_level = float(input('masukkan nilai kontras [1.0 - 3.0]: '))
except ValueError:
  print('Error, not a number')

image1 = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/female.tiff')
formatted_image1 = np.zeros(image1.shape, image1.dtype)

#Akses per piksel
for y in range(image1.shape[0]):
  for x in range(image1.shape[1]):
    for c in range(image1.shape[2]):
      formatted_image1[y,x,c] = np.clip(contrast_level * image1[y,x,c] + brightness_level, 0, 255)

final_frame = cv.hconcat((image1, formatted_image1))
cv2_imshow(final_frame)
# Out:
# Mengubah Kontras dan Tingkat Kecerahan Citra
# --------------------------------------------
# masukkan nilai kecerahan [-255 - 255]: 60
# masukkan nilai kontras [1.0 - 3.0]: 1.5
# <PIL.Image.Image image mode=RGB size=512x256 at 0x7F80232245B0>

# %% [markdown]
# **Implementasikan transformasi logarithmic brightness**

# %%
import math

print('Mengubah Tingkat Kecerahan Citra dengan Transformasi Log')
print('--------------------------------------------')
try:
  brightness_level = int(input('masukkan nilai kecerahan: '))
except ValueError:
  print('Error, not a number')


image2 = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/female.tiff')
formatted_image2 = np.zeros(image2.shape, image2.dtype)


#Akses per piksel
for y in range(image2.shape[0]):
  for x in range(image2.shape[1]):
    for c in range(image2.shape[2]):
      formatted_image2[y,x,c] = np.clip(50 * math.log(1 + image2[y,x,c]), 0, 255)


final_frame = cv.hconcat((image2, formatted_image2))
cv2_imshow(final_frame)
# Out:
# Mengubah Tingkat Kecerahan Citra dengan Transformasi Log
# --------------------------------------------
# masukkan nilai kecerahan: 40
# <PIL.Image.Image image mode=RGB size=512x256 at 0x7F8023224340>

# %% [markdown]
# **Tidak menggunakan library**

# %%
print('Masukkan tingkat kecerahan dengan Transformasi Log ')
print('---------------------------------------------------')

try:
  brightness = int(input('Masukkan nilai kecerahan : '))
except ValueError:
  print('Error, not a number')

log_image = brightness * (np.log(1 + image2))
log_image = np.array(log_image, dtype = np.uint8)

final_frame = cv.hconcat((image2, log_image))
cv2_imshow(final_frame)
# Out:
# Masukkan tingkat kecerahan dengan Transformasi Log
# ---------------------------------------------------
# Masukkan nilai kecerahan : 40
# <PIL.Image.Image image mode=RGB size=512x256 at 0x7F80231FFBB0>

# %% [markdown]
# **Implementasikan transformasi grayscale menggunakan metode averaging, lightness, dan luminance**

# %%
import matplotlib.pyplot as plt

print('Implementasi Transformasi Grayscale')
print('-----------------------------------')

image3 = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/mandrill.tiff')
averaging_image3 = np.zeros(image3.shape, image3.dtype)

image3 = cv.cvtColor(image3, cv.COLOR_BGR2RGB)

#Akses per piksel
for y in range(image3.shape[0]):
  for x in range(image3.shape[1]):
    blue = image3.item(y,x,0)
    green = image3.item(y,x,1)
    red = image3.item(y,x,2)
    average = (blue + green + red) / 3
    averaging_image3[y,x] = [average, average, average]
    

print('Averaging')
averaging_frame = cv.hconcat((image3, averaging_image3))
plt.imshow(averaging_frame)
# Out:
# Implementasi Transformasi Grayscale
# -----------------------------------
# Averaging

# %%
import matplotlib.pyplot as plt

print('Implementasi Transformasi Grayscale')
print('-----------------------------------')

image3 = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/mandrill.tiff')
lightness_image3 = np.zeros(image3.shape, image3.dtype)

image3 = cv.cvtColor(image3, cv.COLOR_BGR2RGB)

#Akses per piksel
for y in range(image3.shape[0]):
  for x in range(image3.shape[1]):
    blue = image3.item(y,x,0)
    green = image3.item(y,x,1)
    red = image3.item(y,x,2)
    maxBGR = max(blue,green,red)
    minBGR = min(blue, green, red)
    lightness_value = (maxBGR + minBGR) / 2
    lightness_image3[y,x] = [lightness_value, lightness_value, lightness_value]
    
  
print('Lightness')
lightness_frame = cv.hconcat((image3, lightness_image3))
plt.imshow(lightness_frame)
# Out:
# Implementasi Transformasi Grayscale
# -----------------------------------
# Lightness

# %%
import matplotlib.pyplot as plt

print('Implementasi Transformasi Grayscale')
print('-----------------------------------')

image3 = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/mandrill.tiff')
lightness_image3 = np.zeros(image3.shape, image3.dtype)

image3 = cv.cvtColor(image3, cv.COLOR_BGR2RGB)

#Akses per piksel
for y in range(image3.shape[0]):
  for x in range(image3.shape[1]):
    blue = image3.item(y,x,0)
    green = image3.item(y,x,1)
    red = image3.item(y,x,2)
    maxBGR = max(blue,green,red)
    minBGR = min(blue, green, red)
    lightness_value = (maxBGR + minBGR) / 2
    lightness_image3[y,x] = [lightness_value, lightness_value, lightness_value]
    
  
print('Lightness')
lightness_frame = cv.hconcat((image3, lightness_image3))
plt.imshow(lightness_frame)
# Out:
# Implementasi Transformasi Grayscale
# -----------------------------------
# Lightness

# %%
import matplotlib.pyplot as plt

print('Implementasi Transformasi Grayscale')
print('-----------------------------------')

image3 = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/mandrill.tiff')
luminance_image3 = np.zeros(image3.shape, image3.dtype)

image3 = cv.cvtColor(image3, cv.COLOR_BGR2RGB)

#Akses per piksel
for y in range(image3.shape[0]):
  for x in range(image3.shape[1]):
    blue = image3.item(y,x,0)
    green = image3.item(y,x,1)
    red = image3.item(y,x,2)
    maxBGR = max(blue,green,red)
    minBGR = min(blue, green, red)
    luminance_value = 0.21 * red + 0.72 * green + 0.07 * blue
    luminance_image3[y,x] = [luminance_value, luminance_value, luminance_value]
    
  
print('Luminance')
luminance_frame = cv.hconcat((image3, luminance_image3))
plt.imshow(luminance_frame)
# Out:
# Implementasi Transformasi Grayscale
# -----------------------------------
# Luminance

# %% [markdown]
# **Tampilkanlah warna tertentu pada citra, dan ubah warna lain menjadi grayscale.**

# %%
print('Inverse')
print('--------------------------------------------------------------------')

img_gray = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/mandrill.tiff')
img_gray = cv.cvtColor(img_gray,cv.COLOR_BGR2RGB)

temp = np.array(img_gray)
for y in range(img_gray.shape[0]):
    for x in range(img_gray.shape[1]):
        if (temp[y,x,0] < 200 or temp[y,x,1] > 140):
            temp[y,x]= np.mean(temp[y,x])

fig, ax = plt.subplots(1,2)
ax[0].imshow(img_gray)
ax[1].imshow(temp)
# Out:
# Inverse
# --------------------------------------------------------------------
